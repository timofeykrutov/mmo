# %%
import numpy as np
import pandas as pd
import pandasql  as ps

# %%
data = pd.read_csv ('adult.data.csv')
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
print(data['sex'].value_counts()) # 1
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
print(data.loc[data['sex'] == 'Female', 'age'].mean()) # Answer 2
# Out:
# 36.85823043357163

# %%
print((data['native-country'] == "Germany").value_counts()/9713) # Answer 3
# Out:
# False    3.338207
# True     0.014105
# Name: native-country, dtype: float64

# %%
print(data.loc[data['salary']==">50K", 'education'].unique()) # 6
# Out:
# ['HS-grad' 'Masters' 'Bachelors' 'Some-college' 'Assoc-voc' 'Doctorate'
#  'Prof-school' 'Assoc-acdm' '7th-8th' '12th' '10th' '11th' '9th' '5th-6th'
#  '1st-4th']

# %%
mean_less = data.loc[data['salary']=="<=50K", 'age'].mean()  # 4-5
mean_more = data.loc[data['salary']==">50K", 'age'].mean()
std_less = data.loc[data['salary']=="<=50K", 'age'].std()
std_more = data.loc[data['salary']==">50K", 'age'].std() 
print('>50K - The average age of the rich: {}, \n standard deviation: {} \n'.format(mean_more.round(1), std_more.round(1)))
print('<=50K - The average age of the poor: {}, \n standard deviation: {}'.format(mean_less.round(1), std_less.round(1)))
# Out:
# >50K - The average age of the rich: 44.2,
#  standard deviation: 10.5
#
# <=50K - The average age of the poor: 36.8,
#  standard deviation: 14.0

# %%
group = data.groupby(['race','sex']) # 7
group.describe()
# Out:
#                                age                                          \
#                              count       mean        std   min   25%   50%
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                                          fnlwgt                 ...  \
#                              75%   max    count           mean  ...
# race               sex                                          ...
# Amer-Indian-Eskimo Female  46.00  80.0    119.0  112950.731092  ...
#                    Male    45.00  82.0    192.0  125715.364583  ...
# Asian-Pac-Islander Female  43.75  75.0    346.0  147452.075145  ...
#                    Male    46.00  90.0    693.0  166175.865801  ...
# Black              Female  46.00  90.0   1555.0  212971.387781  ...
#                    Male    46.00  90.0   1569.0  242920.644997  ...
# Other              Female  39.00  74.0    109.0  172519.642202  ...
#                    Male    42.00  77.0    162.0  213679.104938  ...
# White              Female  46.00  90.0   8642.0  183549.966906  ...
#                    Male    49.00  90.0  19174.0  188987.386148  ...
#
#                           capital-loss         hours-per-week             \
#                                    75%     max          count       mean
# race               sex
# Amer-Indian-Eskimo Female          0.0  1721.0          119.0  36.579832
#                    Male            0.0  1980.0          192.0  42.197917
# Asian-Pac-Islander Female          0.0  2258.0          346.0  37.439306
#                    Male            0.0  2457.0          693.0  41.468975
# Black              Female          0.0  4356.0         1555.0  36.834084
#                    Male            0.0  2824.0         1569.0  39.997451
# Other              Female          0.0  1740.0          109.0  35.926606
#                    Male            0.0  2179.0          162.0  41.851852
# White              Female          0.0  4356.0         8642.0  36.296691
#                    Male            0.0  3770.0        19174.0  42.668822
#
#
#                                  std  min   25%   50%   75%   max
# race               sex
# Amer-Indian-Eskimo Female  11.046509  4.0  35.0  40.0  40.0  84.0
#                    Male    11.596280  3.0  40.0  40.0  45.0  84.0
# Asian-Pac-Islander Female  12.479459  1.0  35.0  40.0  40.0  99.0
#                    Male    12.387563  1.0  40.0  40.0  45.0  99.0
# Black              Female   9.419960  2.0  35.0  40.0  40.0  99.0
#                    Male    10.909413  1.0  40.0  40.0  40.0  99.0
# Other              Female  10.300761  6.0  30.0  40.0  40.0  65.0
#                    Male    11.084779  5.0  40.0  40.0  40.0  98.0
# White              Female  12.190951  1.0  30.0  40.0  40.0  99.0
#                    Male    12.194633  1.0  40.0  40.0  50.0  99.0
#
# [10 rows x 48 columns]

# %% [raw]
# ANSWER 8

# %%
sex= data['sex'] == 'Male'
mar = data['marital-status'].isin(['Married-civ-spouse', 'Married-spouse-absent' , 'Married-AF-spouse'])
bach = data['marital-status'].isin(['Never-married', 'Separated', 'Divorced','Widowed'])
print(s)
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32556     True
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: marital-status, Length: 32561, dtype: bool

# %%
data.loc[sex & mar, 'salary'].value_counts()
# Out:
# <=50K    7576
# >50K     5965
# Name: salary, dtype: int64

# %%
data.loc[sex & bach, 'salary'].value_counts()
# Out:
# <=50K    7552
# >50K      697
# Name: salary, dtype: int64

# %%
print(data['hours-per-week'].max())
# Out:
# 99

# %%
(data['hours-per-week'] == 99).value_counts()
# Out:
# False    32476
# True        85
# Name: hours-per-week, dtype: int64

# %%
data.loc[data['hours-per-week'] == 99, 'salary'].value_counts()
# Out:
# <=50K    60
# >50K     25
# Name: salary, dtype: int64

# %%
25/85*100

# %% [markdown]
# # 10. Count the average time of work (hours-per-week) for those who earn a little and a lot (salary) for each country (native-country). What will these be for Japan?

# %%
group_sal = data.groupby(['native-country','salary'])
group_sal['hours-per-week'].mean().round(1)
# Out:
# native-country  salary
# ?               <=50K     40.2
#                 >50K      45.5
# Cambodia        <=50K     41.4
#                 >50K      40.0
# Canada          <=50K     37.9
#                           ...
# United-States   >50K      45.5
# Vietnam         <=50K     37.2
#                 >50K      39.2
# Yugoslavia      <=50K     41.6
#                 >50K      49.5
# Name: hours-per-week, Length: 82, dtype: float64

# %%
for (country, salary), avg in group_sal:
    print(country, salary, round(avg['hours-per-week'].mean(), 3))
# Out:
# ? <=50K 40.165
# ? >50K 45.548
# Cambodia <=50K 41.417
# Cambodia >50K 40.0
# Canada <=50K 37.915
# Canada >50K 45.641
# China <=50K 37.382
# China >50K 38.9
# Columbia <=50K 38.684
# Columbia >50K 50.0
# Cuba <=50K 37.986
# Cuba >50K 42.44
# Dominican-Republic <=50K 42.338
# Dominican-Republic >50K 47.0
# Ecuador <=50K 38.042
# Ecuador >50K 48.75
# El-Salvador <=50K 36.031
# El-Salvador >50K 45.0
# England <=50K 40.483
# England >50K 44.533
# France <=50K 41.059
# France >50K 50.75
# Germany <=50K 39.14
# Germany >50K 44.977
# Greece <=50K 41.81
# Greece >50K 50.625
# Guatemala <=50K 39.361
# Guatemala >50K 36.667
# Haiti <=50K 36.325
# Haiti >50K 42.75
# Holand-Netherlands <=50K 40.0
# Honduras <=50K 34.333
# Honduras >50K 60.0
# Hong <=50K 39.143
# Hong >50K 45.0
# Hungary <=50K 31.3
# Hungary >50K 50.0
# India <=50K 38.233
# India >50K 46.475
# Iran <=50K 41.44
# Iran >50K 47.5
# Ireland <=50K 40.947
# Ireland >50K 48.0
# Italy <=50K 39.625
# Italy >50K 45.4
# Jamaica <=50K 38.239
# Jamaica >50K 41.1
# Japan <=50K 41.0
# Japan >50K 47.958
# Laos <=50K 40.375
# Laos >50K 40.0
# Mexico <=50K 40.003
# Mexico >50K 46.576
# Nicaragua <=50K 36.094
# Nicaragua >50K 37.5
# Outlying-US(Guam-USVI-etc) <=50K 41.857
# Peru <=50K 35.069
# Peru >50K 40.0
# Philippines <=50K 38.066
# Philippines >50K 43.033
# Poland <=50K 38.167
# Poland >50K 39.0
# Portugal <=50K 41.939
# Portugal >50K 41.5
# Puerto-Rico <=50K 38.471
# Puerto-Rico >50K 39.417
# Scotland <=50K 39.444
# Scotland >50K 46.667
# South <=50K 40.156
# South >50K 51.438
# Taiwan <=50K 33.774
# Taiwan >50K 46.8
# Thailand <=50K 42.867
# Thailand >50K 58.333
# Trinadad&Tobago <=50K 37.059
# Trinadad&Tobago >50K 40.0
# United-States <=50K 38.799
# United-States >50K 45.505
# Vietnam <=50K 37.194
# Vietnam >50K 39.2
# Yugoslavia <=50K 41.6
# Yugoslavia >50K 49.5

# %%
jap1 = group_sal.get_group(('Japan','<=50K'))
jap2 = group_sal.get_group(('Japan','>50K'))
hour1 = jap1['hours-per-week'].mean().round(1)
hour2 = jap2['hours-per-week'].mean().round(1)
print ( 'Japan - >50K - hours-per-week: {} \n Japan - <=50K - hours-per-week: {} '.format(hour1, hour2))
# Out:
# Japan - >50K - hours-per-week: 41.0
#  Japan - <=50K - hours-per-week: 48.0

# %% [markdown]
# # PANDASQL

# %%
user_usage = pd.read_csv('user_usage.csv')
user_device = pd.read_csv('user_device.csv')
android_devices = pd.read_csv('android_devices.csv')

# %%
user_usage.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
user_device.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
android_devices.head(10)
# Out:
#               Retail Branding      Marketing Name              Device  \
# 0                         NaN                 NaN              AD681H
# 1                         NaN                 NaN               FJL21
# 2                         NaN                 NaN                 T31
# 3                         NaN                 NaN            hws7721g
# 4                          3Q             OC1020A             OC1020A
# 5                     7Eleven               IN265               IN265
# 6  A.O.I. ELECTRONICS FACTORY              A.O.I.          TR10CS1_11
# 7                   AG Mobile          AG BOOST 2              BOOST2
# 8                   AG Mobile            AG Flair            AG_Flair
# 9                   AG Mobile  AG Go Tab Access 2  AG_Go_Tab_Access_2
#
#                        Model
# 0  Smartfren Andromax AD681H
# 1                      FJL21
# 2              Panasonic T31
# 3         MediaPad 7 Youth 2
# 4                    OC1020A
# 5                      IN265
# 6                    TR10CS1
# 7                      E4010
# 8                      Flair
# 9         AG_Go_Tab_Access_2

# %%
import time

# %%
def resultpanda():
    result = pd.merge (user_usage, user_device
                [['use_id', 'platform', 'device']], 
                on = 'use_id')
    return result

# %%
data_mobile = resultpanda()
data_mobile.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F
# 2  android  SM-G930F
# 3  android     D2303
# 4  android  SM-G361F

# %%
start_time = time.time()
resultpanda()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.007946252822875977 seconds ---

# %%
def resultSQL (user_usage, user_device):
    join_query = '''
        SELECT 
            usage.outgoing_mins_per_month,
            usage.outgoing_sms_per_month,
            usage.monthly_mb,
            usage.use_id,
            device.platform, device.device
        
        FROM user_usage AS usage 
        JOIN user_device AS device ON (usage.use_id = device.use_id)
    
    
    '''
    return ps.sqldf(join_query, locals())

# %%
start_time = time.time()
resultSQL(user_usage,user_device)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.019946813583374023 seconds ---

# %%
group = resultpanda().groupby('device')['outgoing_mins_per_month'].mean()
group
# Out:
# device
# A0001                      170.395000
# C6603                       92.520000
# D2303                       96.845000
# D5503                      146.450000
# D5803                      244.880000
# D6603                      362.010000
# E6653                      135.090000
# EVA-L09                    115.260000
# F3111                       46.262500
# GT-I8190N                   85.970000
# GT-I9195                   199.430000
# GT-I9300                   167.560000
# GT-I9505                   162.770909
# GT-I9506                   119.800000
# GT-I9515                   180.310000
# GT-N7100                    16.340000
# HTC Desire 510             797.060000
# HTC Desire 530             287.740000
# HTC Desire 620              12.850000
# HTC Desire 626             250.870000
# HTC Desire 825              57.030000
# HTC One M9                 129.850000
# HTC One S                   74.590000
# HTC One mini 2              78.800000
# HTC One_M8                  22.850000
# HUAWEI CUN-L01             124.700000
# HUAWEI VNS-L31               4.620000
# LG-H815                    155.710000
# Lenovo K51c78              215.920000
# Moto G (4)                 103.390000
# MotoE2(4G-LTE)              70.340000
# Nexus 5X                    67.350000
# ONE A2003                  447.085000
# ONEPLUS A3003              301.104286
# SM-A300FU                  124.960000
# SM-A310F                   103.970000
# SM-A500FU                  125.320000
# SM-G360F                    68.170000
# SM-G361F                    65.858000
# SM-G531F                   180.180000
# SM-G800F                    74.230000
# SM-G900F                   178.825333
# SM-G903F                   248.950000
# SM-G920F                   192.882000
# SM-G925F                   155.345000
# SM-G930F                  1161.240000
# SM-G935F                   325.834000
# SM-J320FN                  183.402000
# SM-N9005                   205.110000
# SM-N910F                   152.142000
# VF-795                      57.660000
# Vodafone Smart ultra 6      42.750000
# X11                         60.650000
# iPhone6,2                   50.680000
# iPhone7,2                  681.440000
# Name: outgoing_mins_per_month, dtype: float64

# %%
start_time = time.time()
group = resultpanda().groupby('device')['outgoing_mins_per_month'].mean()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.010970592498779297 seconds ---

# %%
query = '''
    SELECT
        device,
        avg('outgoing_mins_per_month') 
    FROM data_mobile
    GROUP BY device
    '''
result = ps.sqldf(query, locals())
# Out:
#                     device  avg('outgoing_mins_per_month')
# 0                    A0001                             0.0
# 1                    C6603                             0.0
# 2                    D2303                             0.0
# 3                    D5503                             0.0
# 4                    D5803                             0.0
# 5                    D6603                             0.0
# 6                    E6653                             0.0
# 7                  EVA-L09                             0.0
# 8                    F3111                             0.0
# 9                GT-I8190N                             0.0
# 10                GT-I9195                             0.0
# 11                GT-I9300                             0.0
# 12                GT-I9505                             0.0
# 13                GT-I9506                             0.0
# 14                GT-I9515                             0.0
# 15                GT-N7100                             0.0
# 16          HTC Desire 510                             0.0
# 17          HTC Desire 530                             0.0
# 18          HTC Desire 620                             0.0
# 19          HTC Desire 626                             0.0
# 20          HTC Desire 825                             0.0
# 21              HTC One M9                             0.0
# 22               HTC One S                             0.0
# 23          HTC One mini 2                             0.0
# 24              HTC One_M8                             0.0
# 25          HUAWEI CUN-L01                             0.0
# 26          HUAWEI VNS-L31                             0.0
# 27                 LG-H815                             0.0
# 28           Lenovo K51c78                             0.0
# 29              Moto G (4)                             0.0
# 30          MotoE2(4G-LTE)                             0.0
# 31                Nexus 5X                             0.0
# 32               ONE A2003                             0.0
# 33           ONEPLUS A3003                             0.0
# 34               SM-A300FU                             0.0
# 35                SM-A310F                             0.0
# 36               SM-A500FU                             0.0
# 37                SM-G360F                             0.0
# 38                SM-G361F                             0.0
# 39                SM-G531F                             0.0
# 40                SM-G800F                             0.0
# 41                SM-G900F                             0.0
# 42                SM-G903F                             0.0
# 43                SM-G920F                             0.0
# 44                SM-G925F                             0.0
# 45                SM-G930F                             0.0
# 46                SM-G935F                             0.0
# 47               SM-J320FN                             0.0
# 48                SM-N9005                             0.0
# 49                SM-N910F                             0.0
# 50                  VF-795                             0.0
# 51  Vodafone Smart ultra 6                             0.0
# 52                     X11                             0.0
# 53               iPhone6,2                             0.0
# 54               iPhone7,2                             0.0

# %%
start_time = time.time()
result = ps.sqldf(query, locals())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.012966394424438477 seconds ---
