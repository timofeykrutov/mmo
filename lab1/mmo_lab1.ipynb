# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
dataset = pd.read_csv('wine.csv', sep = ",")

# %%
dataset.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0     1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1     1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2     1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3     1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4     1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
#
# [5 rows x 14 columns]

# %%
dataset.shape
# Out:
# (178, 14)

# %%
dataset.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                        int64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %%
for col in dataset.columns:
  temp_null_count = dataset[dataset[col].isnull()].shape[0]
  print('{} - {}'.format(col, temp_null_count))
# Out:
# Wine - 0
# Alcohol - 0
# Malic.acid - 0
# Ash - 0
# Acl - 0
# Mg - 0
# Phenols - 0
# Flavanoids - 0
# Nonflavanoid.phenols - 0
# Proanth - 0
# Color.int - 0
# Hue - 0
# OD - 0
# Proline - 0

# %%
dataset.describe()
# Out:
#              Wine     Alcohol  Malic.acid  ...         Hue          OD      Proline
# count  178.000000  178.000000  178.000000  ...  178.000000  178.000000   178.000000
# mean     1.938202   13.000618    2.336348  ...    0.957449    2.611685   746.893258
# std      0.775035    0.811827    1.117146  ...    0.228572    0.709990   314.907474
# min      1.000000   11.030000    0.740000  ...    0.480000    1.270000   278.000000
# 25%      1.000000   12.362500    1.602500  ...    0.782500    1.937500   500.500000
# 50%      2.000000   13.050000    1.865000  ...    0.965000    2.780000   673.500000
# 75%      3.000000   13.677500    3.082500  ...    1.120000    3.170000   985.000000
# max      3.000000   14.830000    5.800000  ...    1.710000    4.000000  1680.000000
#
# [8 rows x 14 columns]

# %%
dataset['Acl'].unique()
# Out:
# array([15.6, 11.2, 18.6, 16.8, 21. , 15.2, 14.6, 17.6, 14. , 16. , 18. ,
#        11.4, 12. , 17.2, 20. , 16.5, 16.6, 17.8, 25. , 16.1, 17. , 19.4,
#        22.5, 19.1, 19.5, 19. , 20.5, 15.5, 13.2, 16.2, 18.8, 15. , 17.5,
#        18.9, 17.4, 12.4, 17.1, 16.4, 16.3, 16.7, 10.6, 18.1, 19.6, 20.4,
#        24. , 30. , 14.8, 23. , 22.8, 26. , 21.6, 23.6, 18.5, 22. , 20.7,
#        21.5, 20.8, 28.5, 26.5, 24.5, 23.5, 25.5, 27. ])

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='Wine', y='Acl', data=dataset)
#не работает

# %%
sns.jointplot(x = 'Acl', y = 'Wine', data= dataset, kind = 'kde')

# %%
sns.jointplot(x = )

# %%
sns.boxplot(x=dataset['Acl'])

# %%
sns.boxplot(y=dataset['Hue'])

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(dataset['Mg'])

# %%
sns.jointplot(x='Wine', y='Alcohol', data=dataset, kind="hex")

# %%
dataset.corr()
# Out:
#                           Wine   Alcohol  ...        OD   Proline
# Wine                  1.000000 -0.328222  ... -0.788230 -0.633717
# Alcohol              -0.328222  1.000000  ...  0.072343  0.643720
# Malic.acid            0.437776  0.094397  ... -0.368710 -0.192011
# Ash                  -0.049643  0.211545  ...  0.003911  0.223626
# Acl                   0.517859 -0.310235  ... -0.276769 -0.440597
# Mg                   -0.209179  0.270798  ...  0.066004  0.393351
# Phenols              -0.719163  0.289101  ...  0.699949  0.498115
# Flavanoids           -0.847498  0.236815  ...  0.787194  0.494193
# Nonflavanoid.phenols  0.489109 -0.155929  ... -0.503270 -0.311385
# Proanth              -0.499130  0.136698  ...  0.519067  0.330417
# Color.int             0.265668  0.546364  ... -0.428815  0.316100
# Hue                  -0.617369 -0.071747  ...  0.565468  0.236183
# OD                   -0.788230  0.072343  ...  1.000000  0.312761
# ...

# %%
sns.heatmap(dataset.corr())

# %%
sns.heatmap(dataset.corr(), annot=True, fmt='.1f')
